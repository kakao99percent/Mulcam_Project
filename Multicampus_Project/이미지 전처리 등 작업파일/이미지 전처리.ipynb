# %%
import warnings
warnings.filterwarnings('always')
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd

import os, sys, json, cv2

import matplotlib.pyplot as plt
import seaborn as sns

import urllib.request
import pandas as pd

from PIL import Image
from sklearn import datasets
import shutil

# %%
from google.colab.patches import cv2_imshow

# %% [markdown]
# ## Set1

# %%
def sharp(name, file_path, save_path):
  file = os.listdir(file_path)

  for img_name in file :
    image = cv2.imread(f"{file_path}/{img_name}")
    kernel = np.array([[0, -1, 0],
                    [-1, 5,-1],
                    [0, -1, 0]])
    image_sharp = cv2.filter2D(image, -1, kernel)
    # save
    cv2.imwrite(f'{save_path}/sharp_{name}_{img_name}',image_sharp)

# %%
name = 'nor'
file_path = '/content/drive/MyDrive/3조/조세익/전처리/resize/정상'
save_path = '/content/drive/MyDrive/3조/Dog_Pic/전처리 이미지(학습용)/치와와/set_1/set_1_nor'
sharp(name, file_path, save_path)

# %%
name = 'fat'
file_path = '/content/drive/MyDrive/3조/조세익/전처리/resize/비만'
save_path = '/content/drive/MyDrive/3조/Dog_Pic/전처리 이미지(학습용)/치와와/set_1/set_1_fat'
sharp(name, file_path, save_path)

# %%
print(len(os.listdir('/content/drive/MyDrive/3조/조세익/전처리/resize/정상')))
print(len(os.listdir('/content/drive/MyDrive/3조/Dog_Pic/전처리 이미지(학습용)/치와와/set_1/set_1_nor')))
print(len(os.listdir('/content/drive/MyDrive/3조/Dog_Pic/전처리 이미지(학습용)/치와와/set_1/set_1_fat')))
# Out:
# 728
# 728
# 200

# %% [markdown]
# ### Set 분할

# %%
base_dir = '/content/drive/MyDrive/3조/Dog_Pic/전처리 이미지(학습용)/치와와/set_1'

train_path = os.path.join(base_dir, 'train')
os.mkdir( train_path)
val_path = os.path.join(base_dir, 'validation')
os.mkdir( val_path)
test_path = os.path.join(base_dir, 'test')
os.mkdir( test_path)
train_nor_path = os.path.join(train_path, 'nor')
os.mkdir( train_nor_path)
train_fat_path = os.path.join(train_path, 'fat')
os.mkdir( train_fat_path)
val_nor_path = os.path.join(val_path, 'nor')
os.mkdir( val_nor_path)
val_fat_path = os.path.join(val_path, 'fat')
os.mkdir( val_fat_path)
test_nor_path = os.path.join(test_path, 'nor')
os.mkdir( test_nor_path)
test_fat_path = os.path.join(test_path, 'fat')
os.mkdir( test_fat_path)

nor_path = '/content/drive/MyDrive/3조/Dog_Pic/전처리 이미지(학습용)/치와와/set_1/set_1_nor'
nor_list = os.listdir(nor_path)
fat_path = '/content/drive/MyDrive/3조/Dog_Pic/전처리 이미지(학습용)/치와와/set_1/set_1_fat'
fat_list = os.listdir(fat_path)

for i in range(0, int(len(nor_list)*0.5)):
  src_path = os.path.join(nor_path, nor_list[i])                 # 원본 파일 경로
  dst_path = os.path.join(train_nor_path, f'nor_{i}.jpg')        # 복사할 파일 경로
  shutil.copyfile( src_path, dst_path )

for i in range(0, int(len(fat_list)*0.5)):
  src_path = os.path.join(fat_path, fat_list[i])        
  dst_path = os.path.join(train_fat_path, f'fat_{i}.jpg')   
  shutil.copyfile( src_path, dst_path )

for i in range(int(len(nor_list)*0.5), int(len(nor_list)*0.75)):
  src_path = os.path.join(nor_path, nor_list[i])        
  dst_path = os.path.join(val_nor_path, f'nor_{i}.jpg')   
  shutil.copyfile( src_path, dst_path )

for i in range(int(len(fat_list)*0.5), int(len(fat_list)*0.75)):
  src_path = os.path.join(fat_path, fat_list[i])        
  dst_path = os.path.join(val_fat_path, f'fat_{i}.jpg')   
  shutil.copyfile( src_path, dst_path )

for i in range(int(len(nor_list)*0.75), len(nor_list)):
  src_path = os.path.join(nor_path, nor_list[i])        
  dst_path = os.path.join(test_nor_path, f'nor_{i}.jpg')   
  shutil.copyfile( src_path, dst_path )

for i in range(int(len(fat_list)*0.75), len(fat_list)):
  src_path = os.path.join(fat_path, fat_list[i])        
  dst_path = os.path.join(test_fat_path, f'fat_{i}.jpg')   
  shutil.copyfile( src_path, dst_path )

print(f'train set : {len(os.listdir(train_nor_path)) + len(os.listdir(train_fat_path))}')
print(f'validation set : {len(os.listdir(val_nor_path)) + len(os.listdir(val_fat_path))}')
print(f'test set : {len(os.listdir(test_nor_path)) + len(os.listdir(test_fat_path))}')
print(f'total set : {len(nor_list) + len(fat_list)}')
# Out:
# train set : 464
# validation set : 232
# test set : 232
# total set : 928

# %% [markdown]
# ## Set2

# %%
def GaussianBlur(name, file_path, save_path):
  file = os.listdir(file_path)

  for img_name in file:
    image = cv2.imread(f"{file_path}/{img_name}")
    #각 픽셀 주변의 5X5커널 평균값으로 이미지를 흐리게 
    image_very_blurry = cv2.GaussianBlur(image, (5,5), 0) # 가우시안 블러를 적용
    cv2.imwrite(f'{save_path}/GaussianBlur_{name}_{img_name}',image_very_blurry)

# %%
name = 'nor'
file_path = '/content/drive/MyDrive/3조/조세익/전처리/resize/정상'
save_path = '/content/drive/MyDrive/3조/Dog_Pic/전처리 이미지(학습용)/치와와/Set_2/set_2_nor'
GaussianBlur(name,file_path, save_path)

# %%
name = 'fat'
file_path = '/content/drive/MyDrive/3조/조세익/전처리/resize/비만'
save_path = '/content/drive/MyDrive/3조/Dog_Pic/전처리 이미지(학습용)/치와와/Set_2/set_2_fat'
GaussianBlur(name,file_path, save_path)

# %% [markdown]
# ### Set 분할

# %%
base_dir = '/content/drive/MyDrive/3조/Dog_Pic/전처리 이미지(학습용)/치와와/Set_2'

train_path = os.path.join(base_dir, 'train')
os.mkdir( train_path)
val_path = os.path.join(base_dir, 'validation')
os.mkdir( val_path)
test_path = os.path.join(base_dir, 'test')
os.mkdir( test_path)
train_nor_path = os.path.join(train_path, 'nor')
os.mkdir( train_nor_path)
train_fat_path = os.path.join(train_path, 'fat')
os.mkdir( train_fat_path)
val_nor_path = os.path.join(val_path, 'nor')
os.mkdir( val_nor_path)
val_fat_path = os.path.join(val_path, 'fat')
os.mkdir( val_fat_path)
test_nor_path = os.path.join(test_path, 'nor')
os.mkdir( test_nor_path)
test_fat_path = os.path.join(test_path, 'fat')
os.mkdir( test_fat_path)

nor_path = '/content/drive/MyDrive/3조/Dog_Pic/전처리 이미지(학습용)/치와와/Set_2/set_2_nor'
nor_list = os.listdir(nor_path)
fat_path = '/content/drive/MyDrive/3조/Dog_Pic/전처리 이미지(학습용)/치와와/Set_2/set_2_fat'
fat_list = os.listdir(fat_path)

for i in range(0, int(len(nor_list)*0.5)):
  src_path = os.path.join(nor_path, nor_list[i])                 # 원본 파일 경로
  dst_path = os.path.join(train_nor_path, f'nor_{i}.jpg')        # 복사할 파일 경로
  shutil.copyfile( src_path, dst_path )

for i in range(0, int(len(fat_list)*0.5)):
  src_path = os.path.join(fat_path, fat_list[i])        
  dst_path = os.path.join(train_fat_path, f'fat_{i}.jpg')   
  shutil.copyfile( src_path, dst_path )

for i in range(int(len(nor_list)*0.5), int(len(nor_list)*0.75)):
  src_path = os.path.join(nor_path, nor_list[i])        
  dst_path = os.path.join(val_nor_path, f'nor_{i}.jpg')   
  shutil.copyfile( src_path, dst_path )

for i in range(int(len(fat_list)*0.5), int(len(fat_list)*0.75)):
  src_path = os.path.join(fat_path, fat_list[i])        
  dst_path = os.path.join(val_fat_path, f'fat_{i}.jpg')   
  shutil.copyfile( src_path, dst_path )

for i in range(int(len(nor_list)*0.75), len(nor_list)):
  src_path = os.path.join(nor_path, nor_list[i])        
  dst_path = os.path.join(test_nor_path, f'nor_{i}.jpg')   
  shutil.copyfile( src_path, dst_path )

for i in range(int(len(fat_list)*0.75), len(fat_list)):
  src_path = os.path.join(fat_path, fat_list[i])        
  dst_path = os.path.join(test_fat_path, f'fat_{i}.jpg')   
  shutil.copyfile( src_path, dst_path )

print(f'train set : {len(os.listdir(train_nor_path)) + len(os.listdir(train_fat_path))}')
print(f'validation set : {len(os.listdir(val_nor_path)) + len(os.listdir(val_fat_path))}')
print(f'test set : {len(os.listdir(test_nor_path)) + len(os.listdir(test_fat_path))}')
print(f'total set : {len(nor_list) + len(fat_list)}')
# Out:
# train set : 464
# validation set : 232
# test set : 232
# total set : 928

# %% [markdown]
# ## Set3

# %%
def Grayscale_sharp(name, file_path, save_path):
  file = os.listdir(file_path)

  for img_name in file:
    image = cv2.imread(f"{file_path}/{img_name}",cv2.IMREAD_GRAYSCALE) # 흑백 이미지로 로드
    kernel = np.array([[0, -1, 0],
                    [-1, 5,-1],
                    [0, -1, 0]]) # 커널 생성
    # 이미지를 선명하게 만듦
    image_sharp = cv2.filter2D(image, -1, kernel)
    # save
    cv2.imwrite(f'{save_path}/Grayscale_sharp_{name}_{img_name}',image_sharp)

# %%
name = 'nor'
file_path = '/content/drive/MyDrive/3조/조세익/전처리/resize/정상'
save_path = '/content/drive/MyDrive/3조/Dog_Pic/전처리 이미지(학습용)/치와와/Set_3/set_3_nor'
Grayscale_sharp(name,file_path, save_path)

# %%
name = 'fat'
file_path = '/content/drive/MyDrive/3조/조세익/전처리/resize/비만'
save_path = '/content/drive/MyDrive/3조/Dog_Pic/전처리 이미지(학습용)/치와와/Set_3/set_3_fat'
Grayscale_sharp(name,file_path, save_path)

# %%
print(len(os.listdir('/content/drive/MyDrive/3조/조세익/전처리/resize/정상')))
print(len(os.listdir('/content/drive/MyDrive/3조/Dog_Pic/전처리 이미지(학습용)/치와와/Set_3/set_3_nor')))
print(len(os.listdir('/content/drive/MyDrive/3조/Dog_Pic/전처리 이미지(학습용)/치와와/Set_3/set_3_fat')))
# Out:
# 728
# 728
# 200

# %% [markdown]
# ### Set 분할

# %%
base_dir = '/content/drive/MyDrive/3조/Dog_Pic/전처리 이미지(학습용)/치와와/Set_3'

train_path = os.path.join(base_dir, 'train')
os.mkdir( train_path)
val_path = os.path.join(base_dir, 'validation')
os.mkdir( val_path)
test_path = os.path.join(base_dir, 'test')
os.mkdir( test_path)
train_nor_path = os.path.join(train_path, 'nor')
os.mkdir( train_nor_path)
train_fat_path = os.path.join(train_path, 'fat')
os.mkdir( train_fat_path)
val_nor_path = os.path.join(val_path, 'nor')
os.mkdir( val_nor_path)
val_fat_path = os.path.join(val_path, 'fat')
os.mkdir( val_fat_path)
test_nor_path = os.path.join(test_path, 'nor')
os.mkdir( test_nor_path)
test_fat_path = os.path.join(test_path, 'fat')
os.mkdir( test_fat_path)

nor_path = '/content/drive/MyDrive/3조/Dog_Pic/전처리 이미지(학습용)/치와와/Set_3/set_3_nor'
nor_list = os.listdir(nor_path)
fat_path = '/content/drive/MyDrive/3조/Dog_Pic/전처리 이미지(학습용)/치와와/Set_3/set_3_fat'
fat_list = os.listdir(fat_path)

for i in range(0, int(len(nor_list)*0.5)):
  src_path = os.path.join(nor_path, nor_list[i])                 # 원본 파일 경로
  dst_path = os.path.join(train_nor_path, f'nor_{i}.jpg')        # 복사할 파일 경로
  shutil.copyfile( src_path, dst_path )

for i in range(0, int(len(fat_list)*0.5)):
  src_path = os.path.join(fat_path, fat_list[i])        
  dst_path = os.path.join(train_fat_path, f'fat_{i}.jpg')   
  shutil.copyfile( src_path, dst_path )

for i in range(int(len(nor_list)*0.5), int(len(nor_list)*0.75)):
  src_path = os.path.join(nor_path, nor_list[i])        
  dst_path = os.path.join(val_nor_path, f'nor_{i}.jpg')   
  shutil.copyfile( src_path, dst_path )

for i in range(int(len(fat_list)*0.5), int(len(fat_list)*0.75)):
  src_path = os.path.join(fat_path, fat_list[i])        
  dst_path = os.path.join(val_fat_path, f'fat_{i}.jpg')   
  shutil.copyfile( src_path, dst_path )

for i in range(int(len(nor_list)*0.75), len(nor_list)):
  src_path = os.path.join(nor_path, nor_list[i])        
  dst_path = os.path.join(test_nor_path, f'nor_{i}.jpg')   
  shutil.copyfile( src_path, dst_path )

for i in range(int(len(fat_list)*0.75), len(fat_list)):
  src_path = os.path.join(fat_path, fat_list[i])        
  dst_path = os.path.join(test_fat_path, f'fat_{i}.jpg')   
  shutil.copyfile( src_path, dst_path )

print(f'train set : {len(os.listdir(train_nor_path)) + len(os.listdir(train_fat_path))}')
print(f'validation set : {len(os.listdir(val_nor_path)) + len(os.listdir(val_fat_path))}')
print(f'test set : {len(os.listdir(test_nor_path)) + len(os.listdir(test_fat_path))}')
print(f'total set : {len(nor_list) + len(fat_list)}')
# Out:
# train set : 464
# validation set : 232
# test set : 232
# total set : 928

# %% [markdown]
# ## Set4

# %%
def Grayscale_GaussianBlur(name, file_path, save_path):
  file = os.listdir(file_path)

  for img_name in file:
    image = cv2.imread(f"{file_path}/{img_name}", cv2.IMREAD_GRAYSCALE) # 흑백 이미지로 로드
    #각 픽셀 주변의 5X5커널 평균값으로 이미지를 흐리게 
    image_very_blurry = cv2.GaussianBlur(image, (5,5), 0) # 가우시안 블러를 적용
    cv2.imwrite(f'{save_path}/Grayscale_GaussianBlur_{name}_{img_name}',image_very_blurry)

# %%
name = 'nor'
file_path = '/content/drive/MyDrive/3조/조세익/전처리/resize/정상'
save_path = '/content/drive/MyDrive/3조/Dog_Pic/전처리 이미지(학습용)/치와와/Set_4/set_4_nor'
Grayscale_GaussianBlur(name,file_path, save_path)

# %%
name = 'fat'
file_path = '/content/drive/MyDrive/3조/조세익/전처리/resize/비만'
save_path = '/content/drive/MyDrive/3조/Dog_Pic/전처리 이미지(학습용)/치와와/Set_4/set_4_fat'
Grayscale_GaussianBlur(name,file_path, save_path)

# %%
print(len(os.listdir('/content/drive/MyDrive/3조/조세익/전처리/resize/정상')))
print(len(os.listdir('/content/drive/MyDrive/3조/Dog_Pic/전처리 이미지(학습용)/치와와/Set_4/set_4_nor')))
print(len(os.listdir('/content/drive/MyDrive/3조/Dog_Pic/전처리 이미지(학습용)/치와와/Set_4/set_4_fat')))
# Out:
# 728
# 728
# 200

# %% [markdown]
# ### Set 분할

# %%
base_dir = '/content/drive/MyDrive/3조/Dog_Pic/전처리 이미지(학습용)/치와와/Set_4'

train_path = os.path.join(base_dir, 'train')
os.mkdir( train_path)
val_path = os.path.join(base_dir, 'validation')
os.mkdir( val_path)
test_path = os.path.join(base_dir, 'test')
os.mkdir( test_path)
train_nor_path = os.path.join(train_path, 'nor')
os.mkdir( train_nor_path)
train_fat_path = os.path.join(train_path, 'fat')
os.mkdir( train_fat_path)
val_nor_path = os.path.join(val_path, 'nor')
os.mkdir( val_nor_path)
val_fat_path = os.path.join(val_path, 'fat')
os.mkdir( val_fat_path)
test_nor_path = os.path.join(test_path, 'nor')
os.mkdir( test_nor_path)
test_fat_path = os.path.join(test_path, 'fat')
os.mkdir( test_fat_path)

nor_path = '/content/drive/MyDrive/3조/Dog_Pic/전처리 이미지(학습용)/치와와/Set_4/set_4_nor'
nor_list = os.listdir(nor_path)
fat_path = '/content/drive/MyDrive/3조/Dog_Pic/전처리 이미지(학습용)/치와와/Set_4/set_4_fat'
fat_list = os.listdir(fat_path)

for i in range(0, int(len(nor_list)*0.5)):
  src_path = os.path.join(nor_path, nor_list[i])                 # 원본 파일 경로
  dst_path = os.path.join(train_nor_path, f'nor_{i}.jpg')        # 복사할 파일 경로
  shutil.copyfile( src_path, dst_path )

for i in range(0, int(len(fat_list)*0.5)):
  src_path = os.path.join(fat_path, fat_list[i])        
  dst_path = os.path.join(train_fat_path, f'fat_{i}.jpg')   
  shutil.copyfile( src_path, dst_path )

for i in range(int(len(nor_list)*0.5), int(len(nor_list)*0.75)):
  src_path = os.path.join(nor_path, nor_list[i])        
  dst_path = os.path.join(val_nor_path, f'nor_{i}.jpg')   
  shutil.copyfile( src_path, dst_path )

for i in range(int(len(fat_list)*0.5), int(len(fat_list)*0.75)):
  src_path = os.path.join(fat_path, fat_list[i])        
  dst_path = os.path.join(val_fat_path, f'fat_{i}.jpg')   
  shutil.copyfile( src_path, dst_path )

for i in range(int(len(nor_list)*0.75), len(nor_list)):
  src_path = os.path.join(nor_path, nor_list[i])        
  dst_path = os.path.join(test_nor_path, f'nor_{i}.jpg')   
  shutil.copyfile( src_path, dst_path )

for i in range(int(len(fat_list)*0.75), len(fat_list)):
  src_path = os.path.join(fat_path, fat_list[i])        
  dst_path = os.path.join(test_fat_path, f'fat_{i}.jpg')   
  shutil.copyfile( src_path, dst_path )

print(f'train set : {len(os.listdir(train_nor_path)) + len(os.listdir(train_fat_path))}')
print(f'validation set : {len(os.listdir(val_nor_path)) + len(os.listdir(val_fat_path))}')
print(f'test set : {len(os.listdir(test_nor_path)) + len(os.listdir(test_fat_path))}')
print(f'total set : {len(nor_list) + len(fat_list)}')
# Out:
# train set : 464
# validation set : 232
# test set : 232
# total set : 928

# %% [markdown]
# ## Set5

# %%
def sharp_contrast(name, file_path, save_path):
  file = os.listdir(file_path)
  i = 0
  for img_name in file:
    image_bgr = cv2.imread(f"{file_path}/{img_name}") # 이미지 로드
    image_yuv = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2YUV) # YUV로 변경
    image_yuv[:, :, 0] = cv2.equalizeHist(image_yuv[:, :, 0]) # 히스토그램 평활화 적용
    # image_rgb = cv2.cvtColor(image_yuv, cv2.COLOR_YUV2RGB) # RGB로 바꿔주지 않을거임
    # save
    i+=1
    cv2.imwrite(f'{save_path}/sharp_contrast_{i}.jpg',image_yuv)

# %%
name = 'nor'
file_path = '/content/drive/MyDrive/3조/조세익/전처리/resize/정상'
save_path = '/content/drive/MyDrive/3조/Dog_Pic/전처리 이미지(학습용)/치와와/Set_5/set_5_nor'
sharp_contrast(name, file_path, save_path)

# %%
name = 'fat'
file_path = '/content/drive/MyDrive/3조/조세익/전처리/resize/비만'
save_path = '/content/drive/MyDrive/3조/Dog_Pic/전처리 이미지(학습용)/치와와/Set_5/set_5_fat'
sharp_contrast(name, file_path, save_path)

# %%
print(len(os.listdir('/content/drive/MyDrive/3조/조세익/전처리/resize/정상')))
print(len(os.listdir('/content/drive/MyDrive/3조/Dog_Pic/전처리 이미지(학습용)/치와와/Set_5/set_5_nor')))
print(len(os.listdir('/content/drive/MyDrive/3조/Dog_Pic/전처리 이미지(학습용)/치와와/Set_5/set_5_fat')))
# Out:
# 728
# 727
# 200

# %% [markdown]
# ### Set 분할

# %%
base_dir = '/content/drive/MyDrive/3조/Dog_Pic/전처리 이미지(학습용)/치와와/Set_5'

train_path = os.path.join(base_dir, 'train')
os.mkdir( train_path)
val_path = os.path.join(base_dir, 'validation')
os.mkdir( val_path)
test_path = os.path.join(base_dir, 'test')
os.mkdir( test_path)
train_nor_path = os.path.join(train_path, 'nor')
os.mkdir( train_nor_path)
train_fat_path = os.path.join(train_path, 'fat')
os.mkdir( train_fat_path)
val_nor_path = os.path.join(val_path, 'nor')
os.mkdir( val_nor_path)
val_fat_path = os.path.join(val_path, 'fat')
os.mkdir( val_fat_path)
test_nor_path = os.path.join(test_path, 'nor')
os.mkdir( test_nor_path)
test_fat_path = os.path.join(test_path, 'fat')
os.mkdir( test_fat_path)

nor_path = '/content/drive/MyDrive/3조/Dog_Pic/전처리 이미지(학습용)/치와와/Set_5/set_5_nor'
nor_list = os.listdir(nor_path)
fat_path = '/content/drive/MyDrive/3조/Dog_Pic/전처리 이미지(학습용)/치와와/Set_5/set_5_fat'
fat_list = os.listdir(fat_path)

for i in range(0, int(len(nor_list)*0.5)):
  src_path = os.path.join(nor_path, nor_list[i])                 # 원본 파일 경로
  dst_path = os.path.join(train_nor_path, f'nor_{i}.jpg')        # 복사할 파일 경로
  shutil.copyfile( src_path, dst_path )

for i in range(0, int(len(fat_list)*0.5)):
  src_path = os.path.join(fat_path, fat_list[i])        
  dst_path = os.path.join(train_fat_path, f'fat_{i}.jpg')   
  shutil.copyfile( src_path, dst_path )

for i in range(int(len(nor_list)*0.5), int(len(nor_list)*0.75)):
  src_path = os.path.join(nor_path, nor_list[i])        
  dst_path = os.path.join(val_nor_path, f'nor_{i}.jpg')   
  shutil.copyfile( src_path, dst_path )

for i in range(int(len(fat_list)*0.5), int(len(fat_list)*0.75)):
  src_path = os.path.join(fat_path, fat_list[i])        
  dst_path = os.path.join(val_fat_path, f'fat_{i}.jpg')   
  shutil.copyfile( src_path, dst_path )

for i in range(int(len(nor_list)*0.75), len(nor_list)):
  src_path = os.path.join(nor_path, nor_list[i])        
  dst_path = os.path.join(test_nor_path, f'nor_{i}.jpg')   
  shutil.copyfile( src_path, dst_path )

for i in range(int(len(fat_list)*0.75), len(fat_list)):
  src_path = os.path.join(fat_path, fat_list[i])        
  dst_path = os.path.join(test_fat_path, f'fat_{i}.jpg')   
  shutil.copyfile( src_path, dst_path )

print(f'train set : {len(os.listdir(train_nor_path)) + len(os.listdir(train_fat_path))}')
print(f'validation set : {len(os.listdir(val_nor_path)) + len(os.listdir(val_fat_path))}')
print(f'test set : {len(os.listdir(test_nor_path)) + len(os.listdir(test_fat_path))}')
print(f'total set : {len(nor_list) + len(fat_list)}')
# Out:
# train set : 464
# validation set : 232
# test set : 232
# total set : 928

# %% [markdown]
# ## Set6

# %%
def div255(name, file_path, save_path):
  file = os.listdir(file_path)

  for img_name in file:
    image = cv2.imread(f"{file_path}/{img_name}")
    image = image/255
    cv2.imwrite(f'{save_path}/div255_{name}_{img_name}',image)

# %%
name = 'nor'
file_path = '/content/drive/MyDrive/3조/조세익/전처리/resize/정상'
save_path = '/content/drive/MyDrive/3조/Dog_Pic/전처리 이미지(학습용)/치와와/Set_6/set_6_nor'
div255(name, file_path, save_path)

# %%
name = 'fat'
file_path = '/content/drive/MyDrive/3조/조세익/전처리/resize/비만'
save_path = '/content/drive/MyDrive/3조/Dog_Pic/전처리 이미지(학습용)/치와와/Set_6/set_6_fat'
div255(name, file_path, save_path)

# %% [markdown]
# ### Set 분할

# %%
base_dir = '/content/drive/MyDrive/3조/Dog_Pic/전처리 이미지(학습용)/치와와/Set_6'

train_path = os.path.join(base_dir, 'train')
os.mkdir( train_path)
val_path = os.path.join(base_dir, 'validation')
os.mkdir( val_path)
test_path = os.path.join(base_dir, 'test')
os.mkdir( test_path)
train_nor_path = os.path.join(train_path, 'nor')
os.mkdir( train_nor_path)
train_fat_path = os.path.join(train_path, 'fat')
os.mkdir( train_fat_path)
val_nor_path = os.path.join(val_path, 'nor')
os.mkdir( val_nor_path)
val_fat_path = os.path.join(val_path, 'fat')
os.mkdir( val_fat_path)
test_nor_path = os.path.join(test_path, 'nor')
os.mkdir( test_nor_path)
test_fat_path = os.path.join(test_path, 'fat')
os.mkdir( test_fat_path)

nor_path = '/content/drive/MyDrive/3조/Dog_Pic/전처리 이미지(학습용)/치와와/Set_6/set_6_nor'
nor_list = os.listdir(nor_path)
fat_path = '/content/drive/MyDrive/3조/Dog_Pic/전처리 이미지(학습용)/치와와/Set_6/set_6_fat'
fat_list = os.listdir(fat_path)

for i in range(0, int(len(nor_list)*0.5)):
  src_path = os.path.join(nor_path, nor_list[i])                 # 원본 파일 경로
  dst_path = os.path.join(train_nor_path, f'nor_{i}.jpg')        # 복사할 파일 경로
  shutil.copyfile( src_path, dst_path )

for i in range(0, int(len(fat_list)*0.5)):
  src_path = os.path.join(fat_path, fat_list[i])        
  dst_path = os.path.join(train_fat_path, f'fat_{i}.jpg')   
  shutil.copyfile( src_path, dst_path )

for i in range(int(len(nor_list)*0.5), int(len(nor_list)*0.75)):
  src_path = os.path.join(nor_path, nor_list[i])        
  dst_path = os.path.join(val_nor_path, f'nor_{i}.jpg')   
  shutil.copyfile( src_path, dst_path )

for i in range(int(len(fat_list)*0.5), int(len(fat_list)*0.75)):
  src_path = os.path.join(fat_path, fat_list[i])        
  dst_path = os.path.join(val_fat_path, f'fat_{i}.jpg')   
  shutil.copyfile( src_path, dst_path )

for i in range(int(len(nor_list)*0.75), len(nor_list)):
  src_path = os.path.join(nor_path, nor_list[i])        
  dst_path = os.path.join(test_nor_path, f'nor_{i}.jpg')   
  shutil.copyfile( src_path, dst_path )

for i in range(int(len(fat_list)*0.75), len(fat_list)):
  src_path = os.path.join(fat_path, fat_list[i])        
  dst_path = os.path.join(test_fat_path, f'fat_{i}.jpg')   
  shutil.copyfile( src_path, dst_path )

print(f'train set : {len(os.listdir(train_nor_path)) + len(os.listdir(train_fat_path))}')
print(f'validation set : {len(os.listdir(val_nor_path)) + len(os.listdir(val_fat_path))}')
print(f'test set : {len(os.listdir(test_nor_path)) + len(os.listdir(test_fat_path))}')
print(f'total set : {len(nor_list) + len(fat_list)}')
# Out:
# train set : 464
# validation set : 232
# test set : 232
# total set : 928
